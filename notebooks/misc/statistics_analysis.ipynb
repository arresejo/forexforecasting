# %%
import sys
import os

sys.path.insert(0, os.path.abspath('../../'))

from src.analysis.statistical_analysis import calculate_stats

# %%
stats_df = calculate_stats(verbose=False)
stats_df
# Out:
#                EURUSD       GBPUSD       USDJPY       USDCHF
# count     2608.000000  2608.000000  2608.000000  2608.000000
# mean        -0.000070    -0.000097     0.000173     0.000022
# std          0.004926     0.005937     0.005626     0.005591
# min         -0.032913    -0.091600    -0.036678    -0.145794
# 25%         -0.002917    -0.003185    -0.002518    -0.002574
# 50%          0.000009    -0.000071     0.000267     0.000146
# 75%          0.002730     0.003170     0.003012     0.002853
# max          0.032797     0.033307     0.043474     0.029410
# skewness    -0.022950    -1.966899    -0.041375    -6.908169
# kurtosis     3.465023    29.979443     5.761165   178.139773
